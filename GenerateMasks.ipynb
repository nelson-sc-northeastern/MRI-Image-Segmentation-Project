# %%
import pandas as pd
import numpy as np
import os
import ast
import matplotlib.pyplot as plt
import cv2

# %%
df_epi = pd.read_csv("EpiduralHemorrhageRemovedFlags.csv")

cond1 = df_epi["Correct Label"].notna()
cond2 = df_epi["Correct Label"].isna()

v1 = df_epi["Correct Label"]
v2 = df_epi["Majority Label"]

df_epi["OutLabel"] = np.select([cond1, cond2], [v1, v2])
df_epi
# Out:
#      Unnamed: 0  Case ID            Origin  \
# 0             0  1196514  ID_004c4b319.jpg
# 1             1  1196682  ID_0237b835f.jpg
# 2             2  1196477  ID_02e2d273d.jpg
# 3             3  1196612  ID_02f37ce84.jpg
# 4             4  1196612  ID_02f37ce84.jpg
# ..          ...      ...               ...
# 604         605  1196614  ID_879afbc77.jpg
# 605         606  1196600  ID_af76460ee.jpg
# 606         607  1196767  ID_d6d369eaa.jpg
# 607         608  1196539  ID_d9bfa60ed.jpg
# 608         609  1196955  ID_fa2874be0.jpg
#
#                                             URL Labeling State  \
# 0    https://go.centaurlabs.com/problem/1196514        Labeled
# 1    https://go.centaurlabs.com/problem/1196682          Ready
# 2    https://go.centaurlabs.com/problem/1196477        Labeled
# 3    https://go.centaurlabs.com/problem/1196612          Ready
# 4    https://go.centaurlabs.com/problem/1196612          Ready
# ..                                          ...            ...
# 604  https://go.centaurlabs.com/problem/1196614          Ready
# 605  https://go.centaurlabs.com/problem/1196600          Ready
# 606  https://go.centaurlabs.com/problem/1196767    In Progress
# 607  https://go.centaurlabs.com/problem/1196539        Labeled
# 608  https://go.centaurlabs.com/problem/1196955        Labeled
#
#                                             All Labels  Total Reads  \
# 0    ['[{"x": 0.40818718, "y": 0.8623607}, {"x": 0....         19.0
# 1    ['[{"x": 0.62959146, "y": 0.720186}, {"x": 0.6...         51.0
# 2    ['[{"x": 0.35205495, "y": 0.34680602}, {"x": 0...         22.0
# 3    ['[{"x": 0.3680166, "y": 0.48387372}, {"x": 0....         51.0
# 4    ['[{"x": 0.3680166, "y": 0.48387372}, {"x": 0....         51.0
# ..                                                 ...          ...
# 604  ['[]' '[]' '[]' '[]' '[]' '[]' '[]' '[]' '[]' ...         52.0
# 605  ['[]' '[]' '[]' '[]' '[]' '[]' '[]' '[]' '[]' ...         52.0
# 606                         ['[]' '[]' '[]' '[]' '[]']         77.0
# 607          ['[]' '[]' '[]' '[]' '[]' '[]' '[]' '[]']         20.0
# 608               ['[]' '[]' '[]' '[]' '[]' '[]' '[]']         18.0
#
#      Total Qualified Reads                                     Majority Label  \
# 0                      5.0  [{"x": 0.537109375, "y": 0.89453125}, {"x": 0....
# 1                     28.0  [{"x": 0.654296875, "y": 0.724609375}, {"x": 0...
# 2                      6.0  [{"x": 0.46484375, "y": 0.357421875}, {"x": 0....
# 3                     29.0  [{"x": 0.431640625, "y": 0.607421875}, {"x": 0...
# 4                     29.0  [{"x": 0.353515625, "y": 0.59765625}, {"x": 0....
# ..                     ...                                                ...
# 604                   29.0                                                 []
# 605                   30.0                                                 []
# 606                    5.0                                                 []
# 607                    8.0                                                 []
# 608                    7.0                                                 []
#
#      Number of ROIs                                      Correct Label  \
# 0               1.0  [[{'x': 0.537109375, 'y': 0.89453125}, {'x': 0...
# 1               1.0                                                NaN
# 2               1.0  [[{'x': 0.46484375, 'y': 0.357421875}, {'x': 0...
# 3               2.0                                                NaN
# 4               2.0                                                NaN
# ..              ...                                                ...
# 604             0.0                                                NaN
# 605             0.0                                                NaN
# 606             0.0                                                NaN
# 607             0.0  [[{'x': 0.443359375, 'y': 0.810546875}, {'x': ...
# 608             0.0  [[{'x': 0.37890625, 'y': 0.318359375}, {'x': 0...
#
#      Difficulty  Agreement Comments  Internal Notes  \
# 0          0.00   0.968851      NaN             NaN
# 1           NaN   0.063519      NaN             NaN
# 2          0.06   0.710300      NaN             NaN
# 3           NaN   0.264134      NaN             NaN
# 4           NaN   0.264134      NaN             NaN
# ..          ...        ...      ...             ...
# 604         NaN   1.000000      NaN             NaN
# 605         NaN   1.000000      NaN             NaN
# 606         NaN   1.000000      NaN             NaN
# 607        0.12   1.000000      NaN             NaN
# 608        0.14   1.000000      NaN             NaN
#
#                                               OutLabel
# 0    [[{'x': 0.537109375, 'y': 0.89453125}, {'x': 0...
# 1    [{"x": 0.654296875, "y": 0.724609375}, {"x": 0...
# 2    [[{'x': 0.46484375, 'y': 0.357421875}, {'x': 0...
# 3    [{"x": 0.431640625, "y": 0.607421875}, {"x": 0...
# 4    [{"x": 0.353515625, "y": 0.59765625}, {"x": 0....
# ..                                                 ...
# 604                                                 []
# 605                                                 []
# 606                                                 []
# 607  [[{'x': 0.443359375, 'y': 0.810546875}, {'x': ...
# 608  [[{'x': 0.37890625, 'y': 0.318359375}, {'x': 0...
#
# [609 rows x 16 columns]

# %%
df_subdur = pd.read_csv("SubduralHemorrhageRemovedFlags.csv")

cond1 = df_subdur["Correct Label"].notna()
cond2 = df_subdur["Correct Label"].isna()

v1 = df_subdur["Correct Label"]
v2 = df_subdur["Majority Label"]

df_subdur["OutLabel"] = np.select([cond1, cond2], [v1, v2])
df_subdur
# Out:
#      Unnamed: 0  Case ID            Origin  \
# 0             0  1198320  ID_0061cb462.jpg
# 1             1  1198320  ID_0061cb462.jpg
# 2             2  1198004  ID_0086b5e67.jpg
# 3             3  1198004  ID_0086b5e67.jpg
# 4             4  1198353  ID_00eb6f7cc.jpg
# ..          ...      ...               ...
# 745         747  1197978  ID_c0bfa10d4.jpg
# 746         748  1198037  ID_04f4f9961.jpg
# 747         749  1198103  ID_39cacf303.jpg
# 748         750  1198171  ID_522d2c708.jpg
# 749         751  1198216  ID_526a44302.jpg
#
#                                             URL Labeling State  \
# 0    https://go.centaurlabs.com/problem/1198320        Labeled
# 1    https://go.centaurlabs.com/problem/1198320        Labeled
# 2    https://go.centaurlabs.com/problem/1198004    In Progress
# 3    https://go.centaurlabs.com/problem/1198004    In Progress
# 4    https://go.centaurlabs.com/problem/1198353        Labeled
# ..                                          ...            ...
# 745  https://go.centaurlabs.com/problem/1197978    In Progress
# 746  https://go.centaurlabs.com/problem/1198037    In Progress
# 747  https://go.centaurlabs.com/problem/1198103    In Progress
# 748  https://go.centaurlabs.com/problem/1198171    In Progress
# 749  https://go.centaurlabs.com/problem/1198216    In Progress
#
#                                             All Labels  Total Reads  \
# 0    ['[{"x": 0.4823523, "y": 0.59177}, {"x": 0.473...         16.0
# 1    ['[{"x": 0.4823523, "y": 0.59177}, {"x": 0.473...         16.0
# 2    ['[{"x": 0.5224404, "y": 0.8304443}, {"x": 0.5...         15.0
# 3    ['[{"x": 0.5224404, "y": 0.8304443}, {"x": 0.5...         15.0
# 4    ['[{"x": 0.48163298, "y": 0.71568763}, {"x": 0...         15.0
# ..                                                 ...          ...
# 745  ['[{"x": 0.6507828, "y": 0.57011575}, {"x": 0....         14.0
# 746                         ['[]' '[]' '[]' '[]' '[]']         15.0
# 747                    ['[]' '[]' '[]' '[]' '[]' '[]']         15.0
# 748                         ['[]' '[]' '[]' '[]' '[]']         15.0
# 749                    ['[]' '[]' '[]' '[]' '[]' '[]']         14.0
#
#      Total Qualified Reads                                     Majority Label  \
# 0                      5.0  [{"x": 0.45703125, "y": 0.78125}, {"x": 0.4570...
# 1                      5.0  [{"x": 0.404296875, "y": 0.333984375}, {"x": 0...
# 2                      6.0  [{"x": 0.521484375, "y": 0.83203125}, {"x": 0....
# 3                      6.0  [{"x": 0.478515625, "y": 0.83984375}, {"x": 0....
# 4                      5.0  [{"x": 0.447265625, "y": 0.73828125}, {"x": 0....
# ..                     ...                                                ...
# 745                    5.0                                                 []
# 746                    5.0                                                 []
# 747                    6.0                                                 []
# 748                    5.0                                                 []
# 749                    6.0                                                 []
#
#      Number of ROIs                                      Correct Label  \
# 0               2.0  [[{'x': 0.40625, 'y': 0.330078125}, {'x': 0.40...
# 1               2.0  [[{'x': 0.40625, 'y': 0.330078125}, {'x': 0.40...
# 2               2.0                                                NaN
# 3               2.0                                                NaN
# 4               1.0  [[{'x': 0.447265625, 'y': 0.73828125}, {'x': 0...
# ..              ...                                                ...
# 745             0.0                                                NaN
# 746             0.0                                                NaN
# 747             0.0                                                NaN
# 748             0.0                                                NaN
# 749             0.0                                                NaN
#
#      Difficulty  Agreement Comments  Internal Notes  \
# 0          0.29   0.949092      NaN             NaN
# 1          0.29   0.949092      NaN             NaN
# 2           NaN   0.157037      NaN             NaN
# 3           NaN   0.157037      NaN             NaN
# 4          0.00   0.306828      NaN             NaN
# ..          ...        ...      ...             ...
# 745         NaN   0.800000      NaN             NaN
# 746         NaN   1.000000      NaN             NaN
# 747         NaN   1.000000      NaN             NaN
# 748         NaN   1.000000      NaN             NaN
# 749         NaN   1.000000      NaN             NaN
#
#                                               OutLabel
# 0    [[{'x': 0.40625, 'y': 0.330078125}, {'x': 0.40...
# 1    [[{'x': 0.40625, 'y': 0.330078125}, {'x': 0.40...
# 2    [{"x": 0.521484375, "y": 0.83203125}, {"x": 0....
# 3    [{"x": 0.478515625, "y": 0.83984375}, {"x": 0....
# 4    [[{'x': 0.447265625, 'y': 0.73828125}, {'x': 0...
# ..                                                 ...
# 745                                                 []
# 746                                                 []
# 747                                                 []
# 748                                                 []
# 749                                                 []
#
# [750 rows x 16 columns]

# %%
df_subarc = pd.read_csv("SubarachnoidHemorrhageRemovedFlags.csv")

cond1 = df_subarc["Correct Label"].notna()
cond2 = df_subarc["Correct Label"].isna()

v1 = df_subarc["Correct Label"]
v2 = df_subarc["Majority Label"]

df_subarc["OutLabel"] = np.select([cond1, cond2], [v1, v2])
df_subarc
# Out:
#       Unnamed: 0  Case ID            Origin  \
# 0              0  1197112  ID_001b1b944.jpg
# 1              1  1197112  ID_001b1b944.jpg
# 2              2  1197112  ID_001b1b944.jpg
# 3              3  1197367  ID_005f428d2.jpg
# 4              4  1197367  ID_005f428d2.jpg
# ...          ...      ...               ...
# 1026        1026  1197026  ID_ffb8b3408.jpg
# 1027        1027  1197288  ID_ffc54be74.jpg
# 1028        1028  1197288  ID_ffc54be74.jpg
# 1029        1029  1197157  ID_0cefcaa16.jpg
# 1030        1030  1197175  ID_ac8229f7a.jpg
#
#                                              URL Labeling State  \
# 0     https://go.centaurlabs.com/problem/1197112    In Progress
# 1     https://go.centaurlabs.com/problem/1197112    In Progress
# 2     https://go.centaurlabs.com/problem/1197112    In Progress
# 3     https://go.centaurlabs.com/problem/1197367        Labeled
# 4     https://go.centaurlabs.com/problem/1197367        Labeled
# ...                                          ...            ...
# 1026  https://go.centaurlabs.com/problem/1197026    In Progress
# 1027  https://go.centaurlabs.com/problem/1197288        Labeled
# 1028  https://go.centaurlabs.com/problem/1197288        Labeled
# 1029  https://go.centaurlabs.com/problem/1197157  Gold Standard
# 1030  https://go.centaurlabs.com/problem/1197175  Gold Standard
#
#                                              All Labels  Total Reads  \
# 0     ['[{"x": 0.43056944, "y": 0.5936399}, {"x": 0....         16.0
# 1     ['[{"x": 0.43056944, "y": 0.5936399}, {"x": 0....         16.0
# 2     ['[{"x": 0.43056944, "y": 0.5936399}, {"x": 0....         16.0
# 3     ['[{"x": 0.59604716, "y": 0.4975766}, {"x": 0....         29.0
# 4     ['[{"x": 0.59604716, "y": 0.4975766}, {"x": 0....         29.0
# ...                                                 ...          ...
# 1026  ['[{"x": 0.61802936, "y": 0.6869475}, {"x": 0....         15.0
# 1027  ['[{"x": 0.60182124, "y": 0.6626198}, {"x": 0....         25.0
# 1028  ['[{"x": 0.60182124, "y": 0.6626198}, {"x": 0....         25.0
# 1029  ['[{"x": 0.48153853, "y": 0.4326744}, {"x": 0....         16.0
# 1030  ['[{"x": 0.39485946, "y": 0.31588602}, {"x": 0...         17.0
#
#       Total Qualified Reads  \
# 0                       5.0
# 1                       5.0
# 2                       5.0
# 3                       5.0
# 4                       5.0
# ...                     ...
# 1026                    5.0
# 1027                    6.0
# 1028                    6.0
# 1029                    5.0
# 1030                    5.0
#
#                                          Majority Label  Number of ROIs  \
# 0     [{"x": 0.314453125, "y": 0.75}, {"x": 0.314453...             3.0
# 1     [{"x": 0.400390625, "y": 0.796875}, {"x": 0.40...             3.0
# 2     [{"x": 0.556640625, "y": 0.302734375}, {"x": 0...             3.0
# 3     [{"x": 0.54296875, "y": 0.763671875}, {"x": 0....             2.0
# 4     [{"x": 0.630859375, "y": 0.30078125}, {"x": 0....             2.0
# ...                                                 ...             ...
# 1026  [{"x": 0.44921875, "y": 0.748046875}, {"x": 0....             1.0
# 1027  [{"x": 0.505859375, "y": 0.734375}, {"x": 0.50...             2.0
# 1028  [{"x": 0.287109375, "y": 0.443359375}, {"x": 0...             2.0
# 1029                                                 []             0.0
# 1030                                                 []             0.0
#
#                                           Correct Label  Difficulty  \
# 0                                                   NaN         NaN
# 1                                                   NaN         NaN
# 2                                                   NaN         NaN
# 3     [[{'x': 0.626953125, 'y': 0.30078125}, {'x': 0...        0.33
# 4     [[{'x': 0.626953125, 'y': 0.30078125}, {'x': 0...        0.33
# ...                                                 ...         ...
# 1026                                                NaN         NaN
# 1027  [[{'x': 0.287109375, 'y': 0.443359375}, {'x': ...        0.15
# 1028  [[{'x': 0.287109375, 'y': 0.443359375}, {'x': ...        0.15
# 1029                                               [[]]        0.00
# 1030  [[{'x': 0.3634235, 'y': 0.3907563}, {'x': 0.36...        0.00
#
#       Agreement  Comments  Internal Notes  \
# 0      0.252748       NaN             NaN
# 1      0.252748       NaN             NaN
# 2      0.252748       NaN             NaN
# 3      0.763632       NaN             NaN
# 4      0.763632       NaN             NaN
# ...         ...       ...             ...
# 1026   0.431073       NaN             NaN
# 1027   0.351496       NaN             NaN
# 1028   0.351496       NaN             NaN
# 1029   0.833333       NaN             NaN
# 1030   0.800000       NaN             NaN
#
#                                                OutLabel
# 0     [{"x": 0.314453125, "y": 0.75}, {"x": 0.314453...
# 1     [{"x": 0.400390625, "y": 0.796875}, {"x": 0.40...
# 2     [{"x": 0.556640625, "y": 0.302734375}, {"x": 0...
# 3     [[{'x': 0.626953125, 'y': 0.30078125}, {'x': 0...
# 4     [[{'x': 0.626953125, 'y': 0.30078125}, {'x': 0...
# ...                                                 ...
# 1026  [{"x": 0.44921875, "y": 0.748046875}, {"x": 0....
# 1027  [[{'x': 0.287109375, 'y': 0.443359375}, {'x': ...
# 1028  [[{'x': 0.287109375, 'y': 0.443359375}, {'x': ...
# 1029                                               [[]]
# 1030  [[{'x': 0.3634235, 'y': 0.3907563}, {'x': 0.36...
#
# [1031 rows x 16 columns]

# %%
df_intra = pd.read_csv("IntraparenchymalHemorrhageRemovedFlags.csv")

cond1 = df_intra["Correct Label"].notna()
cond2 = df_intra["Correct Label"].isna()

v1 = df_intra["Correct Label"]
v2 = df_intra["Majority Label"]

df_intra["OutLabel"] = np.select([cond1, cond2], [v1, v2])
df_intra
# Out:
#       Unnamed: 0  Case ID            Origin  \
# 0              0  1675660  ID_0002081b6.jpg
# 1              1  1675942  ID_0048e60a4.jpg
# 2              2  1197689  ID_0057d2736.jpg
# 3              3  1197754  ID_007cac3b7.jpg
# 4              4  1675775  ID_00b46c6bc.jpg
# ...          ...      ...               ...
# 1278        1283  1676103  ID_2efe8b804.jpg
# 1279        1285  1675679  ID_4d5dac21b.jpg
# 1280        1286  1197797  ID_664eb0683.jpg
# 1281        1287  1197716  ID_e45ff2e50.jpg
# 1282        1288  1197511  ID_f797f771e.jpg
#
#                                              URL Labeling State  \
# 0     https://go.centaurlabs.com/problem/1675660    In Progress
# 1     https://go.centaurlabs.com/problem/1675942    In Progress
# 2     https://go.centaurlabs.com/problem/1197689        Labeled
# 3     https://go.centaurlabs.com/problem/1197754        Labeled
# 4     https://go.centaurlabs.com/problem/1675775    In Progress
# ...                                          ...            ...
# 1278  https://go.centaurlabs.com/problem/1676103    In Progress
# 1279  https://go.centaurlabs.com/problem/1675679    In Progress
# 1280  https://go.centaurlabs.com/problem/1197797        Labeled
# 1281  https://go.centaurlabs.com/problem/1197716        Labeled
# 1282  https://go.centaurlabs.com/problem/1197511        Labeled
#
#                                              All Labels  Total Reads  \
# 0     ['[{"x": 0.31658885, "y": 0.48357323}, {"x": 0...         22.0
# 1     ['[{"x": 0.54811704, "y": 0.5961946}, {"x": 0....         22.0
# 2     ['[{"x": 0.3040109, "y": 0.52168596}, {"x": 0....         46.0
# 3     ['[{"x": 0.41792268, "y": 0.56897116}, {"x": 0...         51.0
# 4     ['[{"x": 0.82215744, "y": 0.20116618}, {"x": 0...         22.0
# ...                                                 ...          ...
# 1278                         ['[]' '[]' '[]' '[]' '[]']         22.0
# 1279                    ['[]' '[]' '[]' '[]' '[]' '[]']         22.0
# 1280               ['[]' '[]' '[]' '[]' '[]' '[]' '[]']         41.0
# 1281               ['[]' '[]' '[]' '[]' '[]' '[]' '[]']         47.0
# 1282               ['[]' '[]' '[]' '[]' '[]' '[]' '[]']         47.0
#
#       Total Qualified Reads  \
# 0                       9.0
# 1                       7.0
# 2                       9.0
# 3                      10.0
# 4                       6.0
# ...                     ...
# 1278                    5.0
# 1279                    6.0
# 1280                    7.0
# 1281                    7.0
# 1282                    7.0
#
#                                          Majority Label  Number of ROIs  \
# 0     [{"x": 0.3046875, "y": 0.484375}, {"x": 0.3046...             1.0
# 1     [{"x": 0.5859375, "y": 0.640625}, {"x": 0.5859...             1.0
# 2     [{"x": 0.3046875, "y": 0.521484375}, {"x": 0.3...             1.0
# 3     [{"x": 0.41015625, "y": 0.615234375}, {"x": 0....             1.0
# 4     [{"x": 0.365234375, "y": 0.693359375}, {"x": 0...             1.0
# ...                                                 ...             ...
# 1278                                                 []             0.0
# 1279                                                 []             0.0
# 1280                                                 []             0.0
# 1281                                                 []             0.0
# 1282                                                 []             0.0
#
#                                           Correct Label  Difficulty  \
# 0                                                   NaN         NaN
# 1                                                   NaN         NaN
# 2     [[{'x': 0.3046875, 'y': 0.521484375}, {'x': 0....        0.02
# 3     [[{'x': 0.4140625, 'y': 0.6171875}, {'x': 0.41...        0.03
# 4                                                   NaN         NaN
# ...                                                 ...         ...
# 1278                                                NaN         NaN
# 1279                                                NaN         NaN
# 1280                                               [[]]        0.00
# 1281                                               [[]]        0.00
# 1282                                               [[]]        0.00
#
#       Agreement Comments  Internal Notes  \
# 0      0.224542      NaN             NaN
# 1      0.772365      NaN             NaN
# 2      0.738368      NaN             NaN
# 3      0.618086      NaN             NaN
# 4      0.006388      NaN             NaN
# ...         ...      ...             ...
# 1278   1.000000      NaN             NaN
# 1279   1.000000      NaN             NaN
# 1280   1.000000      NaN             NaN
# 1281   1.000000      NaN             NaN
# 1282   1.000000      NaN             NaN
#
#                                                OutLabel
# 0     [{"x": 0.3046875, "y": 0.484375}, {"x": 0.3046...
# 1     [{"x": 0.5859375, "y": 0.640625}, {"x": 0.5859...
# 2     [[{'x': 0.3046875, 'y': 0.521484375}, {'x': 0....
# 3     [[{'x': 0.4140625, 'y': 0.6171875}, {'x': 0.41...
# 4     [{"x": 0.365234375, "y": 0.693359375}, {"x": 0...
# ...                                                 ...
# 1278                                                 []
# 1279                                                 []
# 1280                                               [[]]
# 1281                                               [[]]
# 1282                                               [[]]
#
# [1283 rows x 16 columns]

# %%
df_multi = pd.read_csv("MultipleHemorrhageRemovedFlags.csv")

cond1 = df_multi["Correct Label"].notna()
cond2 = df_multi["Correct Label"].isna()

v1 = df_multi["Correct Label"]
v2 = df_multi["Majority Label"]

df_multi["OutLabel"] = np.select([cond1, cond2], [v1, v2])
df_multi
# Out:
#       Unnamed: 0  Case ID            Origin  \
# 0              0  1198534  ID_01af922c3.jpg
# 1              1  1198534  ID_01af922c3.jpg
# 2              2  1198534  ID_01af922c3.jpg
# 3              3  1198791  ID_01c457a64.jpg
# 4              4  1198791  ID_01c457a64.jpg
# ...          ...      ...               ...
# 1042        1049  1198749  ID_feef88292.jpg
# 1043        1050  1198944  ID_ff88e4f59.jpg
# 1044        1051  1198747  ID_ffd581895.jpg
# 1045        1052  1198747  ID_ffd581895.jpg
# 1046        1053  1198747  ID_ffd581895.jpg
#
#                                              URL Labeling State  \
# 0     https://go.centaurlabs.com/problem/1198534    In Progress
# 1     https://go.centaurlabs.com/problem/1198534    In Progress
# 2     https://go.centaurlabs.com/problem/1198534    In Progress
# 3     https://go.centaurlabs.com/problem/1198791        Labeled
# 4     https://go.centaurlabs.com/problem/1198791        Labeled
# ...                                          ...            ...
# 1042  https://go.centaurlabs.com/problem/1198749    In Progress
# 1043  https://go.centaurlabs.com/problem/1198944    In Progress
# 1044  https://go.centaurlabs.com/problem/1198747        Labeled
# 1045  https://go.centaurlabs.com/problem/1198747        Labeled
# 1046  https://go.centaurlabs.com/problem/1198747        Labeled
#
#                                              All Labels  Total Reads  \
# 0     ['[{"x": 0.372072, "y": 0.6399058}, {"x": 0.36...         23.0
# 1     ['[{"x": 0.372072, "y": 0.6399058}, {"x": 0.36...         23.0
# 2     ['[{"x": 0.372072, "y": 0.6399058}, {"x": 0.36...         23.0
# 3     ['[{"x": 0.40734115, "y": 0.5586468}, {"x": 0....         34.0
# 4     ['[{"x": 0.40734115, "y": 0.5586468}, {"x": 0....         34.0
# ...                                                 ...          ...
# 1042  ['[{"x": 0.62021834, "y": 0.4173323}, {"x": 0....         23.0
# 1043  ['[{"x": 0.571793, "y": 0.7068149}, {"x": 0.57...         23.0
# 1044  ['[{"x": 0.37266213, "y": 0.5361894}, {"x": 0....         26.0
# 1045  ['[{"x": 0.37266213, "y": 0.5361894}, {"x": 0....         26.0
# 1046  ['[{"x": 0.37266213, "y": 0.5361894}, {"x": 0....         26.0
#
#       Total Qualified Reads  \
# 0                       6.0
# 1                       6.0
# 2                       6.0
# 3                       6.0
# 4                       6.0
# ...                     ...
# 1042                    5.0
# 1043                    6.0
# 1044                    6.0
# 1045                    6.0
# 1046                    6.0
#
#                                          Majority Label  Number of ROIs  \
# 0     [{"x": 0.396484375, "y": 0.73046875}, {"x": 0....             3.0
# 1     [{"x": 0.619140625, "y": 0.765625}, {"x": 0.61...             3.0
# 2     [{"x": 0.46875, "y": 0.607421875}, {"x": 0.468...             3.0
# 3     [{"x": 0.4375, "y": 0.7109375}, {"x": 0.4375, ...             3.0
# 4     [{"x": 0.546875, "y": 0.671875}, {"x": 0.54687...             3.0
# ...                                                 ...             ...
# 1042  [{"x": 0.53515625, "y": 0.556640625}, {"x": 0....             2.0
# 1043  [{"x": 0.5859375, "y": 0.728515625}, {"x": 0.5...             1.0
# 1044  [{"x": 0.517578125, "y": 0.578125}, {"x": 0.51...             3.0
# 1045  [{"x": 0.341796875, "y": 0.65625}, {"x": 0.341...             3.0
# 1046  [{"x": 0.564453125, "y": 0.4921875}, {"x": 0.5...             3.0
#
#                                           Correct Label  Difficulty  \
# 0                                                   NaN         NaN
# 1                                                   NaN         NaN
# 2                                                   NaN         NaN
# 3     [[{'x': 0.548828125, 'y': 0.6796875}, {'x': 0....        0.48
# 4     [[{'x': 0.548828125, 'y': 0.6796875}, {'x': 0....        0.48
# ...                                                 ...         ...
# 1042                                                NaN         NaN
# 1043                                                NaN         NaN
# 1044  [[{'x': 0.3671875, 'y': 0.666015625}, {'x': 0....        0.14
# 1045  [[{'x': 0.3671875, 'y': 0.666015625}, {'x': 0....        0.14
# 1046  [[{'x': 0.3671875, 'y': 0.666015625}, {'x': 0....        0.14
#
#       Agreement Comments  Internal Notes  \
# 0      0.790347      NaN             NaN
# 1      0.790347      NaN             NaN
# 2      0.790347      NaN             NaN
# 3      0.124994      NaN             NaN
# 4      0.124994      NaN             NaN
# ...         ...      ...             ...
# 1042   0.507757      NaN             NaN
# 1043   0.251714      NaN             NaN
# 1044   0.672953      NaN             NaN
# 1045   0.672953      NaN             NaN
# 1046   0.672953      NaN             NaN
#
#                                                OutLabel
# 0     [{"x": 0.396484375, "y": 0.73046875}, {"x": 0....
# 1     [{"x": 0.619140625, "y": 0.765625}, {"x": 0.61...
# 2     [{"x": 0.46875, "y": 0.607421875}, {"x": 0.468...
# 3     [[{'x': 0.548828125, 'y': 0.6796875}, {'x': 0....
# 4     [[{'x': 0.548828125, 'y': 0.6796875}, {'x': 0....
# ...                                                 ...
# 1042  [{"x": 0.53515625, "y": 0.556640625}, {"x": 0....
# 1043  [{"x": 0.5859375, "y": 0.728515625}, {"x": 0.5...
# 1044  [[{'x': 0.3671875, 'y': 0.666015625}, {'x': 0....
# 1045  [[{'x': 0.3671875, 'y': 0.666015625}, {'x': 0....
# 1046  [[{'x': 0.3671875, 'y': 0.666015625}, {'x': 0....
#
# [1047 rows x 16 columns]

# %%
df_masks = pd.concat([df_multi, df_intra, df_subarc, df_subdur, df_epi], ignore_index=True)
df_masks
# Out:
#       Unnamed: 0  Case ID            Origin  \
# 0              0  1198534  ID_01af922c3.jpg
# 1              1  1198534  ID_01af922c3.jpg
# 2              2  1198534  ID_01af922c3.jpg
# 3              3  1198791  ID_01c457a64.jpg
# 4              4  1198791  ID_01c457a64.jpg
# ...          ...      ...               ...
# 4715         605  1196614  ID_879afbc77.jpg
# 4716         606  1196600  ID_af76460ee.jpg
# 4717         607  1196767  ID_d6d369eaa.jpg
# 4718         608  1196539  ID_d9bfa60ed.jpg
# 4719         609  1196955  ID_fa2874be0.jpg
#
#                                              URL Labeling State  \
# 0     https://go.centaurlabs.com/problem/1198534    In Progress
# 1     https://go.centaurlabs.com/problem/1198534    In Progress
# 2     https://go.centaurlabs.com/problem/1198534    In Progress
# 3     https://go.centaurlabs.com/problem/1198791        Labeled
# 4     https://go.centaurlabs.com/problem/1198791        Labeled
# ...                                          ...            ...
# 4715  https://go.centaurlabs.com/problem/1196614          Ready
# 4716  https://go.centaurlabs.com/problem/1196600          Ready
# 4717  https://go.centaurlabs.com/problem/1196767    In Progress
# 4718  https://go.centaurlabs.com/problem/1196539        Labeled
# 4719  https://go.centaurlabs.com/problem/1196955        Labeled
#
#                                              All Labels  Total Reads  \
# 0     ['[{"x": 0.372072, "y": 0.6399058}, {"x": 0.36...         23.0
# 1     ['[{"x": 0.372072, "y": 0.6399058}, {"x": 0.36...         23.0
# 2     ['[{"x": 0.372072, "y": 0.6399058}, {"x": 0.36...         23.0
# 3     ['[{"x": 0.40734115, "y": 0.5586468}, {"x": 0....         34.0
# 4     ['[{"x": 0.40734115, "y": 0.5586468}, {"x": 0....         34.0
# ...                                                 ...          ...
# 4715  ['[]' '[]' '[]' '[]' '[]' '[]' '[]' '[]' '[]' ...         52.0
# 4716  ['[]' '[]' '[]' '[]' '[]' '[]' '[]' '[]' '[]' ...         52.0
# 4717                         ['[]' '[]' '[]' '[]' '[]']         77.0
# 4718          ['[]' '[]' '[]' '[]' '[]' '[]' '[]' '[]']         20.0
# 4719               ['[]' '[]' '[]' '[]' '[]' '[]' '[]']         18.0
#
#       Total Qualified Reads  \
# 0                       6.0
# 1                       6.0
# 2                       6.0
# 3                       6.0
# 4                       6.0
# ...                     ...
# 4715                   29.0
# 4716                   30.0
# 4717                    5.0
# 4718                    8.0
# 4719                    7.0
#
#                                          Majority Label  Number of ROIs  \
# 0     [{"x": 0.396484375, "y": 0.73046875}, {"x": 0....             3.0
# 1     [{"x": 0.619140625, "y": 0.765625}, {"x": 0.61...             3.0
# 2     [{"x": 0.46875, "y": 0.607421875}, {"x": 0.468...             3.0
# 3     [{"x": 0.4375, "y": 0.7109375}, {"x": 0.4375, ...             3.0
# 4     [{"x": 0.546875, "y": 0.671875}, {"x": 0.54687...             3.0
# ...                                                 ...             ...
# 4715                                                 []             0.0
# 4716                                                 []             0.0
# 4717                                                 []             0.0
# 4718                                                 []             0.0
# 4719                                                 []             0.0
#
#                                           Correct Label  Difficulty  \
# 0                                                   NaN         NaN
# 1                                                   NaN         NaN
# 2                                                   NaN         NaN
# 3     [[{'x': 0.548828125, 'y': 0.6796875}, {'x': 0....        0.48
# 4     [[{'x': 0.548828125, 'y': 0.6796875}, {'x': 0....        0.48
# ...                                                 ...         ...
# 4715                                                NaN         NaN
# 4716                                                NaN         NaN
# 4717                                                NaN         NaN
# 4718  [[{'x': 0.443359375, 'y': 0.810546875}, {'x': ...        0.12
# 4719  [[{'x': 0.37890625, 'y': 0.318359375}, {'x': 0...        0.14
#
#       Agreement Comments  Internal Notes  \
# 0      0.790347      NaN             NaN
# 1      0.790347      NaN             NaN
# 2      0.790347      NaN             NaN
# 3      0.124994      NaN             NaN
# 4      0.124994      NaN             NaN
# ...         ...      ...             ...
# 4715   1.000000      NaN             NaN
# 4716   1.000000      NaN             NaN
# 4717   1.000000      NaN             NaN
# 4718   1.000000      NaN             NaN
# 4719   1.000000      NaN             NaN
#
#                                                OutLabel
# 0     [{"x": 0.396484375, "y": 0.73046875}, {"x": 0....
# 1     [{"x": 0.619140625, "y": 0.765625}, {"x": 0.61...
# 2     [{"x": 0.46875, "y": 0.607421875}, {"x": 0.468...
# 3     [[{'x': 0.548828125, 'y': 0.6796875}, {'x': 0....
# 4     [[{'x': 0.548828125, 'y': 0.6796875}, {'x': 0....
# ...                                                 ...
# 4715                                                 []
# 4716                                                 []
# 4717                                                 []
# 4718  [[{'x': 0.443359375, 'y': 0.810546875}, {'x': ...
# 4719  [[{'x': 0.37890625, 'y': 0.318359375}, {'x': 0...
#
# [4720 rows x 16 columns]

# %%
df_masks = df_masks[["Case ID", "Origin", "All Labels", "OutLabel"]]
df_masks = df_masks[df_masks["OutLabel"] != '[]']
df_masks = df_masks[df_masks["OutLabel"] != '[[], []]']
df_masks["OutLabel"] = df_masks["OutLabel"].apply(lambda x: ast.literal_eval(x))
df_masks["All Labels"] = df_masks["All Labels"].apply(lambda x: ast.literal_eval(x))

# %%
def flat(x):
    res = []
    for i in x:
        if type(i) is list:
            res.extend(i)
    return res if len(res) > 1 else x

def pull(x):
    res = []
    for i in x:
        if type(i) is dict:
            res.append((i['x'], i['y']))
    return res if len(res) > 1 else x

# %%
df_masks["OutLabel"] = df_masks["OutLabel"].apply(lambda x: flat(x))
df_masks["All Labels"] = df_masks["All Labels"].apply(lambda x: flat(x))
df_masks
# Out:
#       Case ID            Origin  \
# 0     1198534  ID_01af922c3.jpg
# 1     1198534  ID_01af922c3.jpg
# 2     1198534  ID_01af922c3.jpg
# 3     1198791  ID_01c457a64.jpg
# 4     1198791  ID_01c457a64.jpg
# ...       ...               ...
# 4699  1196596  ID_a297d5101.jpg
# 4700  1196523  ID_aa6b7bf5d.jpg
# 4712  1196860  ID_f82e15eb5.jpg
# 4718  1196539  ID_d9bfa60ed.jpg
# 4719  1196955  ID_fa2874be0.jpg
#
#                                              All Labels  \
# 0     [[{"x": 0.372072, "y": 0.6399058}, {"x": 0.364...
# 1     [[{"x": 0.372072, "y": 0.6399058}, {"x": 0.364...
# 2     [[{"x": 0.372072, "y": 0.6399058}, {"x": 0.364...
# 3     [[{"x": 0.40734115, "y": 0.5586468}, {"x": 0.4...
# 4     [[{"x": 0.40734115, "y": 0.5586468}, {"x": 0.4...
# ...                                                 ...
# 4699  [[{"x": 0.75402844, "y": 0.68062687}, {"x": 0....
# 4700  [[{"x": 0.2169128, "y": 0.3310322}, {"x": 0.21...
# 4712  [[{"x": 0.429657, "y": 0.864296}, {"x": 0.4877...
# 4718                                 [[][][][][][][][]]
# 4719                                   [[][][][][][][]]
#
#                                                OutLabel
# 0     [{'x': 0.396484375, 'y': 0.73046875}, {'x': 0....
# 1     [{'x': 0.619140625, 'y': 0.765625}, {'x': 0.61...
# 2     [{'x': 0.46875, 'y': 0.607421875}, {'x': 0.468...
# 3     [{'x': 0.548828125, 'y': 0.6796875}, {'x': 0.5...
# 4     [{'x': 0.548828125, 'y': 0.6796875}, {'x': 0.5...
# ...                                                 ...
# 4699  [{'x': 0.541015625, 'y': 0.8125}, {'x': 0.5410...
# 4700  [{'x': 0.220703125, 'y': 0.451171875}, {'x': 0...
# 4712  [{'x': 0.48046875, 'y': 0.8828125}, {'x': 0.48...
# 4718  [{'x': 0.443359375, 'y': 0.810546875}, {'x': 0...
# 4719  [{'x': 0.37890625, 'y': 0.318359375}, {'x': 0....
#
# [4666 rows x 4 columns]

# %%
df_masks["OutLabel"] = df_masks["OutLabel"].apply(lambda x: pull(x))
df_masks["All Labels"] = df_masks["All Labels"].apply(lambda x: pull(x))
df_masks
# Out:
#       Case ID            Origin  \
# 0     1198534  ID_01af922c3.jpg
# 1     1198534  ID_01af922c3.jpg
# 2     1198534  ID_01af922c3.jpg
# 3     1198791  ID_01c457a64.jpg
# 4     1198791  ID_01c457a64.jpg
# ...       ...               ...
# 4699  1196596  ID_a297d5101.jpg
# 4700  1196523  ID_aa6b7bf5d.jpg
# 4712  1196860  ID_f82e15eb5.jpg
# 4718  1196539  ID_d9bfa60ed.jpg
# 4719  1196955  ID_fa2874be0.jpg
#
#                                              All Labels  \
# 0     [[{"x": 0.372072, "y": 0.6399058}, {"x": 0.364...
# 1     [[{"x": 0.372072, "y": 0.6399058}, {"x": 0.364...
# 2     [[{"x": 0.372072, "y": 0.6399058}, {"x": 0.364...
# 3     [[{"x": 0.40734115, "y": 0.5586468}, {"x": 0.4...
# 4     [[{"x": 0.40734115, "y": 0.5586468}, {"x": 0.4...
# ...                                                 ...
# 4699  [[{"x": 0.75402844, "y": 0.68062687}, {"x": 0....
# 4700  [[{"x": 0.2169128, "y": 0.3310322}, {"x": 0.21...
# 4712  [[{"x": 0.429657, "y": 0.864296}, {"x": 0.4877...
# 4718                                 [[][][][][][][][]]
# 4719                                   [[][][][][][][]]
#
#                                                OutLabel
# 0     [(0.396484375, 0.73046875), (0.396484375, 0.72...
# 1     [(0.619140625, 0.765625), (0.619140625, 0.7617...
# 2     [(0.46875, 0.607421875), (0.46875, 0.60546875)...
# 3     [(0.548828125, 0.6796875), (0.548828125, 0.675...
# 4     [(0.548828125, 0.6796875), (0.548828125, 0.675...
# ...                                                 ...
# 4699  [(0.541015625, 0.8125), (0.541015625, 0.810546...
# 4700  [(0.220703125, 0.451171875), (0.220703125, 0.4...
# 4712  [(0.48046875, 0.8828125), (0.48046875, 0.88085...
# 4718  [(0.443359375, 0.810546875), (0.443359375, 0.8...
# 4719  [(0.37890625, 0.318359375), (0.37890625, 0.316...
#
# [4666 rows x 4 columns]

# %%
df = df_masks.groupby('Case ID', sort=False).agg({'Origin': lambda x: x, 'All Labels': lambda x: x,'OutLabel': lambda x: x})
df = df.reset_index()
df
# Out:
#       Case ID                                             Origin  \
# 0     1198534  [ID_01af922c3.jpg, ID_01af922c3.jpg, ID_01af92...
# 1     1198791  [ID_01c457a64.jpg, ID_01c457a64.jpg, ID_01c457...
# 2     1198657               [ID_0230aaa10.jpg, ID_0230aaa10.jpg]
# 3     1198623  [ID_03d9d46c6.jpg, ID_03d9d46c6.jpg, ID_03d9d4...
# 4     1198886               [ID_0449d114e.jpg, ID_0449d114e.jpg]
# ...       ...                                                ...
# 2935  1196596                                   ID_a297d5101.jpg
# 2936  1196523                                   ID_aa6b7bf5d.jpg
# 2937  1196860                                   ID_f82e15eb5.jpg
# 2938  1196539                                   ID_d9bfa60ed.jpg
# 2939  1196955                                   ID_fa2874be0.jpg
#
#                                              All Labels  \
# 0     [[[{"x": 0.372072, "y": 0.6399058}, {"x": 0.36...
# 1     [[[{"x": 0.40734115, "y": 0.5586468}, {"x": 0....
# 2     [[[{"x": 0.7303207, "y": 0.7609329}, {"x": 0.6...
# 3     [[[{"x": 0.4771661, "y": 0.17315423}, {"x": 0....
# 4     [[[{"x": 0.39765015, "y": 0.7408349}, {"x": 0....
# ...                                                 ...
# 2935  [[{"x": 0.75402844, "y": 0.68062687}, {"x": 0....
# 2936  [[{"x": 0.2169128, "y": 0.3310322}, {"x": 0.21...
# 2937  [[{"x": 0.429657, "y": 0.864296}, {"x": 0.4877...
# 2938                                 [[][][][][][][][]]
# 2939                                   [[][][][][][][]]
#
#                                                OutLabel
# 0     [[(0.396484375, 0.73046875), (0.396484375, 0.7...
# 1     [[(0.548828125, 0.6796875), (0.548828125, 0.67...
# 2     [[(0.76171875, 0.646484375), (0.76171875, 0.64...
# 3     [[(0.541015625, 0.7734375), (0.541015625, 0.77...
# 4     [[(0.330078125, 0.3984375), (0.330078125, 0.39...
# ...                                                 ...
# 2935  [(0.541015625, 0.8125), (0.541015625, 0.810546...
# 2936  [(0.220703125, 0.451171875), (0.220703125, 0.4...
# 2937  [(0.48046875, 0.8828125), (0.48046875, 0.88085...
# 2938  [(0.443359375, 0.810546875), (0.443359375, 0.8...
# 2939  [(0.37890625, 0.318359375), (0.37890625, 0.316...
#
# [2940 rows x 4 columns]

# %%
directory = r'C:\Users\Scott\Documents\Masks'
filename = r'savedImage.png'

# %%
ouch = 0

# %%
cnt = 0
for lopts in df["OutLabel"]:
    orgjpeg = df['Origin'][cnt][0] if type(df['Origin'][cnt]) is np.ndarray else df['Origin'][cnt]
    fname = orgjpeg.split('.')[0] + 'mask' + '.png'
    canvas = np.zeros((512, 512,3), np.uint8)
    ouch = cnt
    if type(lopts) is np.ndarray:
        for p in lopts:
            if p != [[]]:
                pts = np.array([[int(x*512), int(y*512)] for (x,y) in p])
                cv2.drawContours(canvas, [pts],-1, (0,255,0), 3)
                cv2.fillPoly(canvas, [pts], color=(255,255,255))
    elif lopts != [[]]:
            pts = np.array([[int(x*512), int(y*512)] for (x,y) in lopts])
            cv2.drawContours(canvas, [pts],-1, (0,255,0), 3)
            cv2.fillPoly(canvas, [pts], color=(255,255,255))
    os.chdir(directory)
    cv2.imwrite(rf'{fname}', canvas)
    cnt += 1

# %%
ouch
# Out:
# 2939
